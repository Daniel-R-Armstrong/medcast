# %%
# default_exp core

# %% [markdown]
# # Core
#
# > API details.

# %%
print ("test")
# Out:
# test

# %%
#hide
from nbdev.showdoc import *

# %%
nbdev_build_docs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f2dbddad847b> in <module>
# ----> 1 nbdev_build_docs
#
# NameError: name 'nbdev_build_docs' is not defined
